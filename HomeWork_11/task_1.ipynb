# %%
from sympy import*
from sympy.plotting import plot
init_printing()
x=Symbol('x')
f=-18*x**3+5*x**2+10*x-30
f
#4.построим график функции
plot(f,(x,-1,2.5))

# %%
#1)определим корни 
solveset(f)
# Out:
# ⎧      ____________________
# ⎪     ╱ 5⋅√218931   127045
# ⎪  3 ╱  ───────── + ──────
# ⎪  ╲╱      108       5832                 565                5
# ⎨- ──────────────────────── - ──────────────────────────── + ──, ─────────────
# ⎪             3                       ____________________   54           ____
# ⎪                                    ╱ 5⋅√218931   127045                ╱ 5⋅√
# ⎪                             972⋅3 ╱  ───────── + ──────        1944⋅3 ╱  ───
# ⎩                                 ╲╱      108       5832              ╲╱
#
#                             ____________________     ⎛
#                            ╱ 5⋅√218931   127045      ⎜
#                         3 ╱  ───────── + ──────      ⎜
# 565                5    ╲╱      108       5832       ⎜              565⋅√3
# ──────────────── + ── + ──────────────────────── + ⅈ⋅⎜- ──────────────────────
# ________________   54              6                 ⎜           _____________
# 218931   127045                                      ⎜          ╱ 5⋅√218931
# ────── + ──────                                      ⎜  1944⋅3 ╱  ───────── +
# 108       5832                                       ⎝       ╲╱      108
#
#                  ____________________⎞
#                 ╱ 5⋅√218931   127045 ⎟
#           √3⋅3 ╱  ───────── + ────── ⎟                                       3
#              ╲╱      108       5832  ⎟               565                5    ╲
# ─────── + ───────────────────────────⎟, ───────────────────────────── + ── + ─
# _______                6             ⎟           ____________________   54
# 127045                               ⎟          ╱ 5⋅√218931   127045
# ──────                               ⎟  1944⋅3 ╱  ───────── + ──────
#  5832                                ⎠       ╲╱      108       5832
#
#    ____________________     ⎛         ____________________
#   ╱ 5⋅√218931   127045      ⎜        ╱ 5⋅√218931   127045
#  ╱  ───────── + ──────      ⎜  √3⋅3 ╱  ───────── + ──────
# ╱      108       5832       ⎜     ╲╱      108       5832                 565⋅√
# ─────────────────────── + ⅈ⋅⎜- ─────────────────────────── + ─────────────────
#           6                 ⎜               6                         ________
#                             ⎜                                        ╱ 5⋅√2189
#                             ⎜                                1944⋅3 ╱  ───────
#                             ⎝                                     ╲╱      108
#
#             ⎞⎫
#             ⎟⎪
#             ⎟⎪
# 3           ⎟⎪
# ────────────⎟⎬
# ____________⎟⎪
# 31   127045 ⎟⎪
# ── + ────── ⎟⎪
#       5832  ⎠⎭

# %%
#Найдем интервалы
res=[-oo,oo]
res[1:1]=solve(diff(f),x)
res
res_incr=[]
res_dicr=[]
for i in range(1,len(res)):
    if is_increasing(f,Interval.open(res[i-1],res[i])):
        res_incr.append(f'{res[i-1]},{res[i]}')
    else:
        res_dicr.append(f'{res[i-1]},{res[i]}')
print(f'убывает {res_dicr}')
print(f'возрастает {res_incr}')
# Out:
# убывает ['-oo,5/54 - sqrt(565)/54', '5/54 + sqrt(565)/54,oo']
# возрастает ['5/54 - sqrt(565)/54,5/54 + sqrt(565)/54']

# %%
#построим вершины
res_func=solve(diff(f),x)
for i in res_func:
    ch=f.subs(x,i)
    if ch<0:
        print(f'{ch} точка максимум от {i}')
    elif ch>0:
        print(f'{ch} точка маинимум от {i}')
    elif ch==0:
        print(f'{ch} находится на оси х')
# Out:
# -785/27 - 5*sqrt(565)/27 + 5*(5/54 - sqrt(565)/54)**2 - 18*(5/54 - sqrt(565)/54)**3 точка максимум от 5/54 - sqrt(565)/54
# -785/27 - 18*(5/54 + sqrt(565)/54)**3 + 5*(5/54 + sqrt(565)/54)**2 + 5*sqrt(565)/27 точка максимум от 5/54 + sqrt(565)/54

# %%
#Проверим знакопостоянство функции
res=[-oo,oo]
res[1:1]=solve(f,x)
res
res_incr=[]
res_dicr=[]
for i in range(1,len(res)):
    if is_increasing(f,Interval.open(res[i-1],res[i])):
        res_incr.append(f'{res[i-1]},{res[i]}')
    else:
        res_dicr.append(f'{res[i-1]},{res[i]}')
print(f'f>0 {res_dicr}')
print(f'f<0 {res_incr}')
# Out:
# f>0 ['-oo,5/54 - 565/(972*(-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3', '5/54 - 565/(972*(-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) - (-1/2 - sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3,5/54 - (-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3))', '5/54 - (-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(-1/2 + sqrt(3)*I/2)*(5*sqrt(218931)/108 + 127045/5832)**(1/3)),-(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) + 5/54', '-(5*sqrt(218931)/108 + 127045/5832)**(1/3)/3 - 565/(972*(5*sqrt(218931)/108 + 127045/5832)**(1/3)) + 5/54,oo']
# f<0 []
