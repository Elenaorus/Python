# %%
from sympy import*
from sympy.plotting import plot
init_printing()
x=Symbol('x')
f=2*x**3+2*x**2-18*x-18
f
#4.построим график функции
plot(f,(x,-3,3))

# %%
#1)определим корни 
solveset(f)
# Out:
# {-3, -1, 3}

# %%
#Найдем интервалы
res=[-oo,oo]
res[1:1]=solve(diff(f),x)
res
res_incr=[]
res_dicr=[]
for i in range(1,len(res)):
    if is_increasing(f,Interval.open(res[i-1],res[i])):
        res_incr.append(f'{res[i-1]},{res[i]}')
    else:
        res_dicr.append(f'{res[i-1]},{res[i]}')
print(f'убывает {res_dicr}')
print(f'возрастает {res_incr}')
# Out:
# убывает ['-oo,-1/3 + 2*sqrt(7)/3', '-2*sqrt(7)/3 - 1/3,oo']
# возрастает ['-1/3 + 2*sqrt(7)/3,-2*sqrt(7)/3 - 1/3']

# %%
#построим вершины
res_func=solve(diff(f),x)
for i in res_func:
    ch=f.subs(x,i)
    if ch<0:
        print(f'{ch} точка максимум от {i}')
    elif ch>0:
        print(f'{ch} точка маинимум от {i}')
    elif ch==0:
        print(f'{ch} находится на оси х')
# Out:
# -12*sqrt(7) - 12 + 2*(-1/3 + 2*sqrt(7)/3)**2 + 2*(-1/3 + 2*sqrt(7)/3)**3 точка максимум от -1/3 + 2*sqrt(7)/3
# 2*(-2*sqrt(7)/3 - 1/3)**3 - 12 + 2*(-2*sqrt(7)/3 - 1/3)**2 + 12*sqrt(7) точка маинимум от -2*sqrt(7)/3 - 1/3

# %%
#Проверим знакопостоянство функции
res=[-oo,oo]
res[1:1]=solve(f,x)
res
res_incr=[]
res_dicr=[]
for i in range(1,len(res)):
    if is_increasing(f,Interval.open(res[i-1],res[i])):
        res_incr.append(f'{res[i-1]},{res[i]}')
    else:
        res_dicr.append(f'{res[i-1]},{res[i]}')
print(f'f>0 {res_dicr}')
print(f'f<0 {res_incr}')
# Out:
# f>0 ['-3,-1', '-1,3']
# f<0 ['-oo,-3', '3,oo']
